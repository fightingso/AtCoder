# %% [markdown]
# <a href="https://colab.research.google.com/github/SO000000/AtCoder/blob/main/StableDiffusion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install diffusers==0.2.4 transformers scipy ftfy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 112 kB 32.1 MB/s
# ...
#      |████████████████████████████████| 4.7 MB 59.0 MB/s
# ...
#      |████████████████████████████████| 53 kB 1.7 MB/s
# ...
#      |████████████████████████████████| 120 kB 74.2 MB/s
# ...
#      |████████████████████████████████| 6.6 MB 54.2 MB/s
# ...

# %%
TOKEN="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"

# %%
from diffusers import StableDiffusionPipeline

# %%
pipe = StableDiffusionPipeline.from_pretrained("CompVis/stable-diffusion-v1-4", use_auth_token=TOKEN)
pipe.to("cuda")
# Out:
# Downloading:   0%|          | 0.00/1.34k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/14.9k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/342 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/543 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/4.56k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.22G [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/209 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/592 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/492M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/525k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/472 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/806 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.06M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/743 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/3.44G [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/71.2k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/522 [00:00<?, ?B/s]
# ...

# %%
pipe.safety_checker = lambda images, **kwargs: (images, False)

# %%
prompt = "realistic picture of japanese graduation, 8 k"
image = pipe(prompt, height=768, width=512, num_inference_steps=50)
# Out:
# 0it [00:00, ?it/s]

# %%
display(image["sample"][0])
# Out:
# <PIL.Image.Image image mode=RGB size=512x768 at 0x7FBD5983EC50>
